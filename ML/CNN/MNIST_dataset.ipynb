# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
file = np.loadtxt(r'C:\Users\ANUNAY CHANDRA\Desktop\ML-from-scratch\ML\CNN\archive\mnist_train.csv',delimiter=',',skiprows=1)

# %%
print('File type :',type(file))
print('File Shape :',np.shape(file))
y = file[:,0]
X = file[:,1:]
print('True labels are stored in y.')
print(f'Pixel grayscale data is stored in X with shape {np.shape(X)}.')
# Out:
# File type : <class 'numpy.ndarray'>
# File Shape : (60000, 785)
# True labels are stored in y.
# Pixel grayscale data is stored in X with shape (60000, 784).

# %%
sample_X = X[1]
sample_image = []
for i in range(28):
    sample_image.append(sample_X[28*i:28*i+28])
sample_image = np.array(sample_image)
print('Sample image shape :',np.shape(sample_image))
print(f'Sample label : {int(y[1])}')
plt.imshow(sample_image,cmap='gray')
plt.show()
# Out:
# Sample image shape : (28, 28)
# Sample label : 0
